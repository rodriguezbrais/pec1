# %%
import requests
from bs4 import BeautifulSoup

# %%
mainLink = "https://www.tripadvisor.es"
ourense = "/Hotels-g644337-Ourense_Province_of_Ourense_Galicia-Hotels.html"

# %%
link = mainLink + ourense

# %%
response = requests.get(link)

# %%
html = BeautifulSoup(response.content)

# %%
hotelsHtml = html.find_all("div", {"class": "listItem"})

# %%
a = 0
for hotelHtml in hotelsHtml:
    if a != 1:
        hotelRef = hotelHtml.find("a", {"class": "property_title"})
        hotelName = hotelRef.get_text()
        hotelLink = hotelRef.get("href")
        print(hotelName)
        print(hotelLink)
        a = a + 1

        link = mainLink + hotelLink
        response = requests.get(link)
        html = BeautifulSoup(response.content)
        reviewsHtml = html.find_all("div", {"data-test-target": "HR_CC_CARD"})
        for review in reviewsHtml:
            reviewRef = review.find("span")
            reviewText = reviewRef.get_text()
            print(reviewText)
# Out:
#       Eurostars Auriense
# /Hotel_Review-g644337-d280940-Reviews-Eurostars_Auriense-Ourense_Province_of_Ourense_Galicia.html

# %%
link = mainLink + '/Hotel_Review-g644337-d280940-Reviews-Eurostars_Auriense-Ourense_Province_of_Ourense_Galicia.html'
print(link)
# Out:
# https://www.tripadvisor.es/Hotel_Review-g644337-d280940-Reviews-Eurostars_Auriense-Ourense_Province_of_Ourense_Galicia.html

# %%
response = requests.get(link)

# %%
html = BeautifulSoup(response.content)

# %%
reviewsHtml = html.find_all("div", {"data-test-target": "HR_CC_CARD"})

# %%
for review in reviewsHtml:
    reviewRef = review.find("span")
    reviewText = reviewRef.get_text()
    print(reviewText)

# %%
html
# Out:
# <!DOCTYPE html>
# ...

# %%
html.prettify()
# Out:
# '<!DOCTYPE html>\n<html lang="es" xmlns:og="http://opengraphprotocol.org/schema/">\n <head>\n  <meta content="text/html; charset=utf-8" http-equiv="content-type"/>\n  <link href="https://static.tacdn.com/favicon.ico?v2" id="favicon" rel="icon" type="image/x-icon"/>\n  <link color="#000000" href="https://static.tacdn.com/img2/brand_refresh/application_icons/mask-icon.svg" rel="mask-icon" sizes="any"/>\n  <meta content="#34e0a1" name="theme-color"/>\n  <meta content="telephone=no" name="format-detection"/>\n  <script type="text/javascript">\n   window.taRollupsAreAsync = true;\n  </script>\n  <link crossorigin="" href="https://static.tacdn.com/css2/webfonts/TripSans/TripSans.css?v1.002" rel="stylesheet"/>\n  <link as="fetch" crossorigin="anonymous" href="/static/decodeKey.txt" rel="preload">\n   <title>\n    EUROSTARS AURIENSE - Ahora 55\xa0€ (antes 8̶9̶\xa0̶€̶) - opiniones, comparación de precios y fotos del hotel - Ourense, España - Tripadvisor\n   </title>\n   <meta content="TripAdv
# ...
